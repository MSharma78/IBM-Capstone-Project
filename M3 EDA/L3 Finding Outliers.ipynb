# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Outliers**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform exploratory data analysis or EDA.
# You will explore the distribution of key variables and focus on identifying outliers in this lab.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# -  Analyze the distribution of key variables in the dataset.
#
# -  Identify and remove outliers using statistical methods.
#
# -  Perform relevant statistical and correlation analysis.

# %% [markdown]
# #### Install and import the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %% [markdown]
# <h3>Step 1: Load and Explore the Dataset</h3>

# %% [markdown]
# Load the dataset into a DataFrame and examine the structure of the data.

# %%
file_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

#Create the dataframe
df = pd.read_csv(file_url)

#Display the top 10 records
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4  Technical documentation;Blogs;Written Tutorial...  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 2             NaN  Appropriate in length       Easy                 NaN    NaN
# 3             NaN               Too long       Easy                 NaN    NaN
# 4             NaN              Too short       Easy                 NaN    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# <h3>Step 2: Plot the Distribution of Industry</h3>

# %% [markdown]
# Explore how respondents are distributed across different industries.
#
# - Plot a bar chart to visualize the distribution of respondents by industry.
#
# - Highlight any notable trends.

# %%
##Write your code here
industry_count = df['Industry'].value_counts().head(15)
plt.bar(industry_count.index, industry_count.values)
plt.figsize=(10,6)
plt.xticks(rotation = 30, ha='right')
plt.title('Industry Distribution')
plt.xlabel('Industries')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <h3>Step 3: Identify High Compensation Outliers</h3>

# %% [markdown]
# Identify respondents with extremely high yearly compensation.
#
# - Calculate basic statistics (mean, median, and standard deviation) for `ConvertedCompYearly`.
#
# - Identify compensation values exceeding a defined threshold (e.g., 3 standard deviations above the mean).

# %%
##Write your code here
mean = df['ConvertedCompYearly'].mean()

# %%
median = df['ConvertedCompYearly'].median()

# %%
std = df['ConvertedCompYearly'].std()

# %%
threshold = mean + (std * 3)

# %%
outliers = df[df['ConvertedCompYearly']>threshold]
outliers
# Out:
#        ResponseId                                         MainBranch  \
# 529           530                     I am a developer by profession
# 828           829                     I am a developer by profession
# 1932         1933                     I am a developer by profession
# 2171         2172                     I am a developer by profession
# 2187         2188                     I am a developer by profession
# 2316         2317                     I am a developer by profession
# 2592         2593                     I am a developer by profession
# 3024         3025                     I am a developer by profession
# 5934         5935                     I am a developer by profession
# 6735         6736                     I am a developer by profession
# 6802         6803                     I am a developer by profession
# 6897         6898                     I am a developer by profession
# 7979         7980                     I am a developer by profession
# 8818         8819                     I am a developer by profession
# 8898         8899                     I am a developer by profession
# 8919         8920                     I am a developer by profession
# 9026         9027  I am not primarily a developer, but I write co...
# 9608         9609                     I am a developer by profession
# 9732         9733  I am not primarily a developer, but I write co...
# 10624       10625                     I am a developer by profession
# 11607       11608                     I am a developer by profession
# 12143       12144                     I am a developer by profession
# 12723       12724                     I am a developer by profession
# 12814       12815                     I am a developer by profession
# 13336       13337  I am not primarily a developer, but I write co...
# 13342       13343                     I am a developer by profession
# 13644       13645                     I am a developer by profession
# 13755       13756                     I am a developer by profession
# 13763       13764                     I am a developer by profession
# 13790       13791                     I am a developer by profession
# 13952       13953                     I am a developer by profession
# 14145       14146  I am not primarily a developer, but I write co...
# 14507       14508                     I am a developer by profession
# 14674       14675                     I am a developer by profession
# 14708       14709                     I am a developer by profession
# 15837       15838                     I am a developer by profession
# 16350       16351                     I am a developer by profession
# 16448       16449                     I am a developer by profession
# 16560       16561                     I am a developer by profession
# 17593       17594                     I am a developer by profession
# 17672       17673                     I am a developer by profession
# 17688       17689                     I am a developer by profession
# 18038       18039  I am not primarily a developer, but I write co...
# 18046       18047                     I am a developer by profession
# 19190       19191                     I am a developer by profession
# 19244       19245                     I am a developer by profession
# 19267       19268                     I am a developer by profession
# 20728       20729                     I am a developer by profession
# 21367       21368                     I am a developer by profession
# 22714       22715                     I am a developer by profession
# 22842       22843                     I am a developer by profession
# 22898       22899                     I am a developer by profession
# 23288       23289  I am not primarily a developer, but I write co...
# 23694       23695                     I am a developer by profession
# 24179       24180                     I am a developer by profession
# 24736       24737                     I am a developer by profession
# 24754       24755                     I am a developer by profession
# 25084       25085  I am not primarily a developer, but I write co...
# 25238       25239                     I am a developer by profession
# 25936       25937                     I am a developer by profession
# 26080       26081  I am not primarily a developer, but I write co...
# 26572       26573                     I am a developer by profession
# 27902       27903  I am not primarily a developer, but I write co...
# 28213       28214                     I am a developer by profession
# 28236       28237                     I am a developer by profession
# 28379       28380                     I am a developer by profession
# 28381       28382                     I am a developer by profession
# 30449       30450                     I am a developer by profession
# 31166       31167                     I am a developer by profession
# 32293       32294                     I am a developer by profession
# 32837       32838                     I am a developer by profession
# 33000       33001                     I am a developer by profession
# 33112       33113                     I am a developer by profession
# 33645       33646                     I am a developer by profession
# 33720       33721                     I am a developer by profession
# 33936       33937                     I am a developer by profession
# 34317       34318                     I am a developer by profession
# 34523       34524                     I am a developer by profession
# 34842       34843                     I am a developer by profession
# 36299       36300                     I am a developer by profession
# 36329       36330                     I am a developer by profession
# 37382       37383                     I am a developer by profession
# 37518       37519                     I am a developer by profession
# 37930       37931                     I am a developer by profession
# 38219       38220  I am not primarily a developer, but I write co...
# 39643       39644                     I am a developer by profession
# 40066       40067                     I am a developer by profession
# 40952       40953                     I am a developer by profession
# 41027       41028                     I am a developer by profession
#
#                      Age                                         Employment  \
# 529      25-34 years old                                Employed, full-time
# 828      35-44 years old                                Employed, full-time
# 1932     25-34 years old                                Employed, full-time
# 2171     35-44 years old                                Employed, full-time
# 2187     35-44 years old                                Employed, full-time
# 2316     45-54 years old                                Employed, full-time
# 2592     35-44 years old                                Employed, full-time
# 3024     35-44 years old  Employed, full-time;Independent contractor, fr...
# 5934     35-44 years old  Independent contractor, freelancer, or self-em...
# 6735     25-34 years old                                Employed, full-time
# 6802     35-44 years old                                Employed, full-time
# 6897     25-34 years old                                Employed, full-time
# 7979     45-54 years old                                Employed, full-time
# 8818     25-34 years old                                Employed, full-time
# 8898     45-54 years old                                Employed, full-time
# 8919     35-44 years old  Employed, full-time;Independent contractor, fr...
# 9026     35-44 years old                                Employed, full-time
# 9608     35-44 years old                                Employed, full-time
# 9732     55-64 years old                                Employed, part-time
# 10624    25-34 years old                                Employed, full-time
# 11607    45-54 years old                                Employed, full-time
# 12143    25-34 years old                                Employed, full-time
# 12723    25-34 years old  Employed, full-time;Independent contractor, fr...
# 12814    35-44 years old                                Employed, full-time
# 13336    25-34 years old                                Employed, part-time
# 13342    45-54 years old                                Employed, full-time
# 13644  65 years or older  Employed, full-time;Independent contractor, fr...
# 13755    55-64 years old  Employed, full-time;Independent contractor, fr...
# 13763    35-44 years old                                Employed, full-time
# 13790    35-44 years old                                Employed, full-time
# 13952    25-34 years old             Student, part-time;Employed, part-time
# 14145    45-54 years old             Employed, full-time;Student, part-time
# 14507    25-34 years old                                Employed, full-time
# 14674    35-44 years old                                Employed, full-time
# 14708    35-44 years old                                Employed, full-time
# 15837    25-34 years old  Independent contractor, freelancer, or self-em...
# 16350    25-34 years old  Independent contractor, freelancer, or self-em...
# 16448    45-54 years old                                Employed, full-time
# 16560    25-34 years old                                Employed, full-time
# 17593    35-44 years old                                Employed, full-time
# 17672    25-34 years old                                Employed, full-time
# 17688    25-34 years old                                Employed, full-time
# 18038    45-54 years old  Independent contractor, freelancer, or self-em...
# 18046    25-34 years old  Employed, full-time;Independent contractor, fr...
# 19190    45-54 years old                                Employed, full-time
# 19244    45-54 years old                                Employed, full-time
# 19267    25-34 years old                                Employed, full-time
# 20728    35-44 years old                                Employed, full-time
# 21367    35-44 years old                                Employed, full-time
# 22714    35-44 years old                                Employed, full-time
# 22842    25-34 years old                                Employed, full-time
# 22898    25-34 years old                                Employed, full-time
# 23288    35-44 years old                                Employed, full-time
# 23694    18-24 years old  Employed, full-time;Independent contractor, fr...
# 24179    55-64 years old                                Employed, full-time
# 24736    35-44 years old                                Employed, full-time
# 24754    25-34 years old                                Employed, full-time
# 25084    25-34 years old  Independent contractor, freelancer, or self-em...
# 25238    18-24 years old  Employed, full-time;Independent contractor, fr...
# 25936    55-64 years old                                Employed, full-time
# 26080    55-64 years old                                Employed, full-time
# 26572    35-44 years old                                Employed, full-time
# 27902    25-34 years old                                Employed, part-time
# 28213    55-64 years old                                Employed, full-time
# 28236    25-34 years old                                Employed, full-time
# 28379    18-24 years old                                Employed, full-time
# 28381    25-34 years old                                Employed, full-time
# 30449    35-44 years old                                Employed, full-time
# 31166    25-34 years old                                Employed, full-time
# 32293    55-64 years old                                Employed, full-time
# 32837    25-34 years old                                Employed, full-time
# 33000    25-34 years old                                Employed, full-time
# 33112    25-34 years old                                Employed, full-time
# 33645    25-34 years old  Independent contractor, freelancer, or self-em...
# 33720    25-34 years old  Independent contractor, freelancer, or self-em...
# 33936    25-34 years old  Independent contractor, freelancer, or self-em...
# 34317    25-34 years old                                Employed, full-time
# 34523    18-24 years old                                Employed, full-time
# 34842    18-24 years old  Independent contractor, freelancer, or self-em...
# 36299    25-34 years old  Employed, full-time;Independent contractor, fr...
# 36329    25-34 years old                                Employed, full-time
# 37382    18-24 years old                                Employed, full-time
# 37518    35-44 years old                                Employed, full-time
# 37930    25-34 years old                                Employed, full-time
# 38219    35-44 years old                                Employed, full-time
# 39643    35-44 years old                                Employed, full-time
# 40066    25-34 years old                                Employed, full-time
# 40952    35-44 years old                                Employed, full-time
# 41027    55-64 years old  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork   Check  \
# 529                               In-person  Apples
# 828    Hybrid (some remote, some in-person)  Apples
# 1932                                 Remote  Apples
# 2171   Hybrid (some remote, some in-person)  Apples
# 2187                                 Remote  Apples
# 2316                                 Remote  Apples
# 2592                                 Remote  Apples
# 3024                                 Remote  Apples
# 5934                              In-person  Apples
# 6735   Hybrid (some remote, some in-person)  Apples
# 6802                              In-person  Apples
# 6897   Hybrid (some remote, some in-person)  Apples
# 7979                                 Remote  Apples
# 8818                                 Remote  Apples
# 8898                                 Remote  Apples
# 8919   Hybrid (some remote, some in-person)  Apples
# 9026   Hybrid (some remote, some in-person)  Apples
# 9608                                 Remote  Apples
# 9732   Hybrid (some remote, some in-person)  Apples
# 10624                             In-person  Apples
# 11607                                Remote  Apples
# 12143                                Remote  Apples
# 12723  Hybrid (some remote, some in-person)  Apples
# 12814                             In-person  Apples
# 13336  Hybrid (some remote, some in-person)  Apples
# 13342                                Remote  Apples
# 13644                                Remote  Apples
# 13755  Hybrid (some remote, some in-person)  Apples
# 13763                                Remote  Apples
# 13790                                Remote  Apples
# 13952  Hybrid (some remote, some in-person)  Apples
# 14145  Hybrid (some remote, some in-person)  Apples
# 14507                                Remote  Apples
# 14674                                Remote  Apples
# 14708  Hybrid (some remote, some in-person)  Apples
# 15837                             In-person  Apples
# 16350                             In-person  Apples
# 16448                                Remote  Apples
# 16560                                Remote  Apples
# 17593                                Remote  Apples
# 17672                                Remote  Apples
# 17688  Hybrid (some remote, some in-person)  Apples
# 18038  Hybrid (some remote, some in-person)  Apples
# 18046  Hybrid (some remote, some in-person)  Apples
# 19190                             In-person  Apples
# 19244                             In-person  Apples
# 19267                             In-person  Apples
# 20728  Hybrid (some remote, some in-person)  Apples
# 21367  Hybrid (some remote, some in-person)  Apples
# 22714  Hybrid (some remote, some in-person)  Apples
# 22842                                Remote  Apples
# 22898  Hybrid (some remote, some in-person)  Apples
# 23288  Hybrid (some remote, some in-person)  Apples
# 23694                                Remote  Apples
# 24179                                Remote  Apples
# 24736                                Remote  Apples
# 24754  Hybrid (some remote, some in-person)  Apples
# 25084                             In-person  Apples
# 25238                             In-person  Apples
# 25936  Hybrid (some remote, some in-person)  Apples
# 26080  Hybrid (some remote, some in-person)  Apples
# 26572                             In-person  Apples
# 27902  Hybrid (some remote, some in-person)  Apples
# 28213  Hybrid (some remote, some in-person)  Apples
# 28236                             In-person  Apples
# 28379  Hybrid (some remote, some in-person)  Apples
# 28381                             In-person  Apples
# 30449                                Remote  Apples
# 31166  Hybrid (some remote, some in-person)  Apples
# 32293                             In-person  Apples
# 32837  Hybrid (some remote, some in-person)  Apples
# 33000                                Remote  Apples
# 33112                             In-person  Apples
# 33645                                Remote  Apples
# 33720                                Remote  Apples
# 33936                                Remote  Apples
# 34317                             In-person  Apples
# 34523                             In-person  Apples
# 34842                                Remote  Apples
# 36299                                Remote  Apples
# 36329  Hybrid (some remote, some in-person)  Apples
# 37382  Hybrid (some remote, some in-person)  Apples
# 37518                                Remote  Apples
# 37930  Hybrid (some remote, some in-person)  Apples
# 38219  Hybrid (some remote, some in-person)  Apples
# 39643                                Remote  Apples
# 40066                                Remote  Apples
# 40952                                Remote  Apples
# 41027                                Remote  Apples
#
#                                         CodingActivities  \
# 529                                                Hobby
# 828    Hobby;Bootstrapping a business;Professional de...
# 1932   Hobby;Professional development or self-paced l...
# 2171                                               Hobby
# 2187            Hobby;Contribute to open-source projects
# 2316                                               Hobby
# 2592                                               Hobby
# 3024                       Hobby;Freelance/contract work
# 5934                                               Hobby
# 6735                        I don’t code outside of work
# 6802                                               Hobby
# 6897   Hobby;Contribute to open-source projects;Profe...
# 7979            Hobby;Contribute to open-source projects
# 8818            Hobby;Contribute to open-source projects
# 8898                                               Hobby
# 8919   Contribute to open-source projects;Professiona...
# 9026   Professional development or self-paced learnin...
# 9608                        I don’t code outside of work
# 9732   Contribute to open-source projects;Bootstrappi...
# 10624                            Freelance/contract work
# 11607                      Hobby;School or academic work
# 12143                           Bootstrapping a business
# 12723  Contribute to open-source projects;Professiona...
# 12814  Hobby;Contribute to open-source projects;Boots...
# 13336                            Freelance/contract work
# 13342           Hobby;Contribute to open-source projects
# 13644                           Bootstrapping a business
# 13755  Other (please specify):;Professional developme...
# 13763  Contribute to open-source projects;Freelance/c...
# 13790           Hobby;Contribute to open-source projects
# 13952  Hobby;Bootstrapping a business;School or acade...
# 14145  Hobby;Contribute to open-source projects;Profe...
# 14507                                              Hobby
# 14674  Hobby;Professional development or self-paced l...
# 14708                            School or academic work
# 15837  Hobby;Contribute to open-source projects;Boots...
# 16350  Hobby;Contribute to open-source projects;Profe...
# 16448  Contribute to open-source projects;Freelance/c...
# 16560           Hobby;Contribute to open-source projects
# 17593  Hobby;Professional development or self-paced l...
# 17672                      Hobby;School or academic work
# 17688           Hobby;Contribute to open-source projects
# 18038                            Other (please specify):
# 18046  Hobby;Contribute to open-source projects;Boots...
# 19190                       I don’t code outside of work
# 19244  Professional development or self-paced learnin...
# 19267  Hobby;Professional development or self-paced l...
# 20728                       I don’t code outside of work
# 21367  Hobby;Contribute to open-source projects;Freel...
# 22714           Hobby;Contribute to open-source projects
# 22842           Hobby;Contribute to open-source projects
# 22898           Hobby;Contribute to open-source projects
# 23288  Professional development or self-paced learnin...
# 23694                            Freelance/contract work
# 24179  Contribute to open-source projects;School or a...
# 24736                                              Hobby
# 24754                                              Hobby
# 25084  Professional development or self-paced learnin...
# 25238  Hobby;Contribute to open-source projects;Boots...
# 25936           Hobby;Contribute to open-source projects
# 26080  Professional development or self-paced learnin...
# 26572  Hobby;School or academic work;Freelance/contra...
# 27902  Professional development or self-paced learnin...
# 28213           Hobby;Contribute to open-source projects
# 28236           Hobby;Contribute to open-source projects
# 28379                 Contribute to open-source projects
# 28381                                              Hobby
# 30449  Bootstrapping a business;Professional developm...
# 31166                                              Hobby
# 32293  Contribute to open-source projects;Freelance/c...
# 32837  Hobby;Contribute to open-source projects;Profe...
# 33000                            Freelance/contract work
# 33112  Hobby;Bootstrapping a business;School or acade...
# 33645  Hobby;Contribute to open-source projects;Boots...
# 33720  Contribute to open-source projects;Freelance/c...
# 33936           Hobby;Contribute to open-source projects
# 34317  Professional development or self-paced learnin...
# 34523  Hobby;Professional development or self-paced l...
# 34842  Contribute to open-source projects;Freelance/c...
# 36299   Bootstrapping a business;Freelance/contract work
# 36329                 Contribute to open-source projects
# 37382                                              Hobby
# 37518  Hobby;Professional development or self-paced l...
# 37930  Hobby;Professional development or self-paced l...
# 38219  Hobby;Contribute to open-source projects;Boots...
# 39643  Hobby;Professional development or self-paced l...
# 40066  Hobby;Contribute to open-source projects;Boots...
# 40952                                              Hobby
# 41027                       I don’t code outside of work
#
#                                                  EdLevel  \
# 529         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 828      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1932        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2171        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2187        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2316      Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 2592        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3024     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5934      Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 6735     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6802        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6897        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 7979        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8818   Some college/university study without earning ...
# 8898        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8919     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9026        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9608        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9732     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10624    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11607    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 12143    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 12723     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 12814    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 13336       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13342    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 13644  Some college/university study without earning ...
# 13755       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13763    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 13790     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 13952  Some college/university study without earning ...
# 14145    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 14507  Some college/university study without earning ...
# 14674    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 14708     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 15837       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16350       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16448       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16560    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 17593       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17672     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 17688       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 18038       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 18046  Some college/university study without earning ...
# 19190    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 19244       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 19267       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 20728       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 21367  Some college/university study without earning ...
# 22714  Some college/university study without earning ...
# 22842                Associate degree (A.A., A.S., etc.)
# 22898       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23288       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23694     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 24179     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 24736       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24754    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 25084                                     Something else
# 25238     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 25936    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 26080  Some college/university study without earning ...
# 26572     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 27902       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28213    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 28236       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28379     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 28381       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 30449       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 31166    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 32293       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 32837       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33000    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 33112       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33645  Some college/university study without earning ...
# 33720       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33936       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 34317    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 34523    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 34842  Secondary school (e.g. American high school, G...
# 36299       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 36329       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 37382  Some college/university study without earning ...
# 37518    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 37930    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 38219  Some college/university study without earning ...
# 39643       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 40066  Some college/university study without earning ...
# 40952  Some college/university study without earning ...
# 41027  Some college/university study without earning ...
#
#                                                LearnCode  \
# 529    Books / Physical media;School (i.e., Universit...
# 828    Books / Physical media;Colleague;On the job tr...
# 1932   Books / Physical media;Colleague;Other online ...
# 2171   On the job training;Other online resources (e....
# 2187   On the job training;Other online resources (e....
# 2316   School (i.e., University, College, etc);Other ...
# 2592   Other online resources (e.g., videos, blogs, f...
# 3024   Books / Physical media;Other online resources ...
# 5934   Books / Physical media;On the job training;Oth...
# 6735   Books / Physical media;Colleague;On the job tr...
# 6802   Books / Physical media;Other online resources ...
# 6897   On the job training;Other online resources (e....
# 7979   Books / Physical media;Other online resources ...
# 8818   Books / Physical media;Colleague;On the job tr...
# 8898   Other online resources (e.g., videos, blogs, f...
# 8919   Books / Physical media;On the job training;Oth...
# 9026                   Colleague;Friend or family member
# 9608   On the job training;Other online resources (e....
# 9732   Books / Physical media;On the job training;Sch...
# 10624  Books / Physical media;Colleague;Online Course...
# 11607  Books / Physical media;Colleague;On the job tr...
# 12143  Books / Physical media;Other online resources ...
# 12723  Books / Physical media;On the job training;Oth...
# 12814  Books / Physical media;On the job training;Sch...
# 13336  Books / Physical media;School (i.e., Universit...
# 13342  Books / Physical media;Colleague;On the job tr...
# 13644        On the job training;Other (please specify):
# 13755  Books / Physical media;Other online resources ...
# 13763  Other online resources (e.g., videos, blogs, f...
# 13790  On the job training;Other online resources (e....
# 13952  Books / Physical media;Other online resources ...
# 14145  Other online resources (e.g., videos, blogs, f...
# 14507  Other online resources (e.g., videos, blogs, f...
# 14674                    Online Courses or Certification
# 14708  Other online resources (e.g., videos, blogs, f...
# 15837  Books / Physical media;Colleague;On the job tr...
# 16350  Books / Physical media;On the job training;Oth...
# 16448            School (i.e., University, College, etc)
# 16560  Books / Physical media;Other online resources ...
# 17593  Books / Physical media;On the job training;Oth...
# 17672  Other online resources (e.g., videos, blogs, f...
# 17688  On the job training;Other online resources (e....
# 18038  Other online resources (e.g., videos, blogs, f...
# 18046  Books / Physical media;Other online resources ...
# 19190  Books / Physical media;Other online resources ...
# 19244  On the job training;Other online resources (e....
# 19267  Books / Physical media;Colleague;On the job tr...
# 20728  Books / Physical media;Other online resources ...
# 21367  Books / Physical media;Other online resources ...
# 22714  Books / Physical media;Colleague;Other online ...
# 22842  Books / Physical media;Other online resources ...
# 22898  Books / Physical media;On the job training;Oth...
# 23288            School (i.e., University, College, etc)
# 23694  On the job training;Other online resources (e....
# 24179  Books / Physical media;On the job training;Oth...
# 24736  Other online resources (e.g., videos, blogs, f...
# 24754  Books / Physical media;On the job training;Oth...
# 25084            School (i.e., University, College, etc)
# 25238  Books / Physical media;Other online resources ...
# 25936  Other online resources (e.g., videos, blogs, f...
# 26080  Books / Physical media;On the job training;Sch...
# 26572  Colleague;On the job training;Other online res...
# 27902                            Friend or family member
# 28213  Books / Physical media;Online Courses or Certi...
# 28236  School (i.e., University, College, etc);Friend...
# 28379  Books / Physical media;On the job training;Oth...
# 28381  Books / Physical media;Other online resources ...
# 30449  Colleague;On the job training;Other online res...
# 31166  Colleague;On the job training;Other online res...
# 32293  Books / Physical media;Other online resources ...
# 32837  Books / Physical media;Colleague;On the job tr...
# 33000  Other online resources (e.g., videos, blogs, f...
# 33112  Books / Physical media;On the job training;Oth...
# 33645  Other online resources (e.g., videos, blogs, f...
# 33720                   Books / Physical media;Colleague
# 33936  On the job training;School (i.e., University, ...
# 34317  Colleague;Other online resources (e.g., videos...
# 34523  On the job training;Online Courses or Certific...
# 34842  Books / Physical media;Other online resources ...
# 36299  Books / Physical media;School (i.e., Universit...
# 36329  Books / Physical media;School (i.e., Universit...
# 37382  Books / Physical media;On the job training;Oth...
# 37518  Other online resources (e.g., videos, blogs, f...
# 37930  Colleague;Other online resources (e.g., videos...
# 38219  On the job training;Other online resources (e....
# 39643  Books / Physical media;On the job training;Oth...
# 40066                            Other (please specify):
# 40952  Books / Physical media;Colleague;Other online ...
# 41027                            Other (please specify):
#
#                                          LearnCodeOnline  ... JobSatPoints_6  \
# 529                                                  NaN  ...           40.0
# 828    Technical documentation;Blogs;Books;Written Tu...  ...           30.0
# 1932   Technical documentation;Blogs;Books;Written Tu...  ...           15.0
# 2171   Technical documentation;Blogs;Written Tutorial...  ...           20.0
# 2187   Technical documentation;Written Tutorials;Stac...  ...            NaN
# 2316                                                 NaN  ...           10.0
# 2592   Technical documentation;Stack Overflow;Social ...  ...            0.0
# 3024   Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 5934   Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 6735                                      Blogs;Books;AI  ...            0.0
# 6802   Technical documentation;Written Tutorials;Soci...  ...           40.0
# 6897   Technical documentation;Written Tutorials;Soci...  ...           30.0
# 7979   Technical documentation;Blogs;Books;Written Tu...  ...           10.0
# 8818   Technical documentation;Books;AI;Online challe...  ...           25.0
# 8898   Technical documentation;Written Tutorials;Stac...  ...           20.0
# 8919   Books;Written Tutorials;Stack Overflow;Coding ...  ...            NaN
# 9026                                                 NaN  ...            NaN
# 9608                    Written Tutorials;Stack Overflow  ...            NaN
# 9732                                                 NaN  ...            NaN
# 10624                                                NaN  ...            9.0
# 11607  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 12143  Technical documentation;Books;Written Tutorial...  ...           80.0
# 12723  Blogs;Stack Overflow;Coding sessions (live or ...  ...          100.0
# 12814                                                NaN  ...           10.0
# 13336                                                NaN  ...           70.0
# 13342  Technical documentation;Blogs;Books;Written Tu...  ...           10.0
# 13644                                                NaN  ...            NaN
# 13755  Technical documentation;Books;Stack Overflow;I...  ...           10.0
# 13763    Technical documentation;Blogs;Stack Overflow;AI  ...            0.0
# 13790  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 13952  Technical documentation;Books;Stack Overflow;H...  ...           10.0
# 14145  Technical documentation;Written Tutorials;Inte...  ...            0.0
# 14507                                                NaN  ...           25.0
# 14674                                                NaN  ...            NaN
# 14708          Technical documentation;Written Tutorials  ...            0.0
# 15837  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 16350  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 16448                                                NaN  ...            NaN
# 16560  Technical documentation;Blogs;Books;Written Tu...  ...           25.0
# 17593  Technical documentation;Books;Written Tutorial...  ...           75.0
# 17672  Technical documentation;Blogs;Stack Overflow;V...  ...           25.0
# 17688  Technical documentation;Books;Written Tutorial...  ...            NaN
# 18038  Coding sessions (live or recorded);Social Medi...  ...            0.0
# 18046  Technical documentation;Blogs;Books;Written Tu...  ...            2.0
# 19190                      Technical documentation;Books  ...           25.0
# 19244  Technical documentation;Blogs;Written Tutorial...  ...            0.0
# 19267  Blogs;Books;Written Tutorials;Stack Overflow;C...  ...           20.0
# 20728  Technical documentation;Blogs;Stack Overflow;I...  ...           60.0
# 21367  Technical documentation;Blogs;Written Tutorial...  ...           60.0
# 22714  Technical documentation;Blogs;Books;Written Tu...  ...           30.0
# 22842  Blogs;Books;Written Tutorials;Stack Overflow;C...  ...           22.0
# 22898       Technical documentation;Blogs;Stack Overflow  ...            NaN
# 23288                                                NaN  ...            NaN
# 23694  Technical documentation;Written Tutorials;Writ...  ...            NaN
# 24179  Technical documentation;Books;Stack Overflow;O...  ...            0.0
# 24736                  Blogs;Stack Overflow;Social Media  ...            NaN
# 24754  Technical documentation;Blogs;Books;Written Tu...  ...           20.0
# 25084                                                NaN  ...            NaN
# 25238  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 25936    Technical documentation;Books;Written Tutorials  ...            NaN
# 26080                                                NaN  ...            0.0
# 26572  Technical documentation;Blogs;Books;Written Tu...  ...           10.0
# 27902                                                NaN  ...           85.0
# 28213                                                NaN  ...            0.0
# 28236                                                NaN  ...            NaN
# 28379  Technical documentation;Blogs;Books;Written Tu...  ...          100.0
# 28381  Technical documentation;Written Tutorials;Stac...  ...           10.0
# 30449  Technical documentation;Blogs;Written Tutorial...  ...            NaN
# 31166  Technical documentation;Blogs;Written Tutorial...  ...           20.0
# 32293  Blogs;Books;Written Tutorials;Stack Overflow;S...  ...            NaN
# 32837  Technical documentation;Blogs;Written Tutorial...  ...           30.0
# 33000  Technical documentation;Written Tutorials;Stac...  ...            NaN
# 33112  Technical documentation;Books;Written Tutorial...  ...          100.0
# 33645  Technical documentation;Written Tutorials;Stac...  ...            NaN
# 33720                                                NaN  ...            NaN
# 33936                                                NaN  ...           20.0
# 34317  Coding sessions (live or recorded);How-to vide...  ...            5.0
# 34523                                                NaN  ...          100.0
# 34842  Technical documentation;Books;Coding sessions ...  ...            NaN
# 36299                                                NaN  ...           10.0
# 36329                                                NaN  ...           25.0
# 37382    Technical documentation;Books;Written Tutorials  ...            NaN
# 37518  Technical documentation;Blogs;Stack Overflow;H...  ...            0.0
# 37930  Technical documentation;Blogs;Written Tutorial...  ...           90.0
# 38219  Books;Written Tutorials;Interactive tutorial;V...  ...            0.0
# 39643  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 40066                                                NaN  ...           20.0
# 40952       Technical documentation;Blogs;Stack Overflow  ...            NaN
# 41027                                                NaN  ...            0.0
#
#       JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 529             20.0            0.0           30.0            10.0
# 828             10.0            0.0            5.0             0.0
# 1932            10.0           15.0           15.0             0.0
# 2171            10.0           20.0           25.0             0.0
# 2187             NaN            NaN            NaN             NaN
# 2316            10.0           40.0            0.0             0.0
# 2592            10.0            0.0            0.0             0.0
# 3024             NaN            NaN            NaN             NaN
# 5934             NaN            NaN            NaN             NaN
# 6735             0.0            0.0            0.0             0.0
# 6802             0.0            0.0           40.0            20.0
# 6897             5.0           15.0            5.0             3.0
# 7979            20.0           15.0           20.0             5.0
# 8818             0.0            0.0            0.0             0.0
# 8898             0.0           40.0            0.0            20.0
# 8919             NaN            NaN            NaN             NaN
# 9026             NaN            NaN            NaN             NaN
# 9608             NaN            NaN            NaN             NaN
# 9732             NaN            NaN            NaN             NaN
# 10624           10.0            7.0            8.0             9.0
# 11607            0.0           50.0           30.0            20.0
# 12143           70.0           10.0            0.0            60.0
# 12723          100.0          100.0          100.0           100.0
# 12814           20.0           20.0           10.0             1.0
# 13336           75.0           65.0           90.0            80.0
# 13342           15.0           10.0           15.0            15.0
# 13644            NaN            NaN            NaN             NaN
# 13755           20.0            0.0           30.0             0.0
# 13763            0.0            0.0            0.0             0.0
# 13790            0.0            0.0            0.0             0.0
# 13952           10.0           20.0           30.0            10.0
# 14145            0.0            0.0            0.0             0.0
# 14507            0.0           25.0            0.0             0.0
# 14674            NaN            NaN            NaN             NaN
# 14708            0.0            0.0            0.0             0.0
# 15837            NaN            NaN            NaN             NaN
# 16350            NaN            NaN            NaN             NaN
# 16448            NaN            NaN            NaN             NaN
# 16560           25.0           10.0           30.0             0.0
# 17593           40.0           30.0           40.0            30.0
# 17672           35.0           20.0           10.0             0.0
# 17688            NaN            NaN            NaN             NaN
# 18038           10.0           10.0            5.0             0.0
# 18046            3.0            5.0           10.0            25.0
# 19190           10.0           10.0            5.0            25.0
# 19244           10.0           20.0           20.0            20.0
# 19267           30.0           30.0            0.0             0.0
# 20728           10.0            0.0           20.0             0.0
# 21367           90.0           80.0           90.0            80.0
# 22714            5.0            0.0            0.0             5.0
# 22842           20.0           10.0           15.0             2.0
# 22898            NaN            NaN            NaN             NaN
# 23288            NaN            NaN            NaN             NaN
# 23694            NaN            NaN            NaN             NaN
# 24179            0.0            0.0           25.0            10.0
# 24736            NaN            NaN            NaN             NaN
# 24754           15.0           10.0            5.0             0.0
# 25084            NaN            NaN            NaN             NaN
# 25238            NaN            NaN            NaN             NaN
# 25936            NaN            NaN            NaN             NaN
# 26080           20.0            0.0            0.0            10.0
# 26572           30.0           20.0           20.0            20.0
# 27902           65.0           70.0           75.0            90.0
# 28213           20.0           30.0           20.0             0.0
# 28236            NaN            NaN            NaN             NaN
# 28379          100.0          100.0          100.0           100.0
# 28381           10.0            0.0           24.0            10.0
# 30449            NaN            NaN            NaN             NaN
# 31166           10.0           15.0           20.0             0.0
# 32293            NaN            NaN            NaN             NaN
# 32837            0.0           15.0            0.0             0.0
# 33000            NaN            NaN            NaN             NaN
# 33112           70.0           70.0            0.0            20.0
# 33645            NaN            NaN            NaN             NaN
# 33720            NaN            NaN            NaN             NaN
# 33936           10.0           10.0            0.0             0.0
# 34317            0.0            0.0            0.0             0.0
# 34523          100.0          100.0          100.0           100.0
# 34842            NaN            NaN            NaN             NaN
# 36299           50.0           30.0            0.0             0.0
# 36329            0.0            0.0           10.0             0.0
# 37382            NaN            NaN            NaN             NaN
# 37518            0.0            0.0            0.0             0.0
# 37930           30.0           20.0           50.0            80.0
# 38219            0.0            0.0            0.0             0.0
# 39643            NaN            NaN            NaN             NaN
# 40066            0.0           20.0            0.0             0.0
# 40952            NaN            NaN            NaN             NaN
# 41027            0.0            0.0            0.0             0.0
#
#       JobSatPoints_11           SurveyLength                  SurveyEase  \
# 529               0.0  Appropriate in length                        Easy
# 828               0.0  Appropriate in length  Neither easy nor difficult
# 1932             15.0  Appropriate in length                        Easy
# 2171              0.0  Appropriate in length                        Easy
# 2187              NaN  Appropriate in length                        Easy
# 2316              0.0               Too long                        Easy
# 2592              0.0  Appropriate in length  Neither easy nor difficult
# 3024              NaN  Appropriate in length                        Easy
# 5934              NaN  Appropriate in length                        Easy
# 6735              0.0               Too long                         NaN
# 6802              0.0               Too long  Neither easy nor difficult
# 6897              7.0  Appropriate in length                        Easy
# 7979              5.0  Appropriate in length  Neither easy nor difficult
# 8818             25.0               Too long  Neither easy nor difficult
# 8898              0.0               Too long                        Easy
# 8919              NaN  Appropriate in length                        Easy
# 9026              NaN  Appropriate in length                        Easy
# 9608              NaN  Appropriate in length  Neither easy nor difficult
# 9732              NaN               Too long  Neither easy nor difficult
# 10624             9.0  Appropriate in length  Neither easy nor difficult
# 11607             0.0  Appropriate in length  Neither easy nor difficult
# 12143            10.0               Too long                   Difficult
# 12723           100.0  Appropriate in length  Neither easy nor difficult
# 12814             4.0  Appropriate in length                        Easy
# 13336            90.0  Appropriate in length                        Easy
# 13342             0.0               Too long                        Easy
# 13644             NaN               Too long                   Difficult
# 13755             0.0               Too long  Neither easy nor difficult
# 13763             0.0               Too long                   Difficult
# 13790             0.0               Too long                   Difficult
# 13952            10.0               Too long                   Difficult
# 14145             0.0               Too long                        Easy
# 14507             0.0               Too long  Neither easy nor difficult
# 14674             NaN  Appropriate in length                        Easy
# 14708             0.0               Too long  Neither easy nor difficult
# 15837             NaN  Appropriate in length                        Easy
# 16350             NaN  Appropriate in length  Neither easy nor difficult
# 16448             NaN               Too long  Neither easy nor difficult
# 16560            10.0  Appropriate in length  Neither easy nor difficult
# 17593            70.0  Appropriate in length                        Easy
# 17672             0.0               Too long  Neither easy nor difficult
# 17688             NaN  Appropriate in length                        Easy
# 18038             5.0               Too long  Neither easy nor difficult
# 18046            10.0  Appropriate in length                        Easy
# 19190             0.0  Appropriate in length  Neither easy nor difficult
# 19244             0.0  Appropriate in length  Neither easy nor difficult
# 19267             0.0  Appropriate in length                        Easy
# 20728             0.0  Appropriate in length  Neither easy nor difficult
# 21367            90.0  Appropriate in length                        Easy
# 22714            10.0               Too long                        Easy
# 22842             2.0  Appropriate in length                        Easy
# 22898             NaN  Appropriate in length  Neither easy nor difficult
# 23288             NaN  Appropriate in length  Neither easy nor difficult
# 23694             NaN               Too long                   Difficult
# 24179            10.0               Too long  Neither easy nor difficult
# 24736             NaN               Too long                        Easy
# 24754             0.0               Too long                        Easy
# 25084             NaN  Appropriate in length                         NaN
# 25238             NaN               Too long                        Easy
# 25936             NaN  Appropriate in length  Neither easy nor difficult
# 26080            20.0  Appropriate in length  Neither easy nor difficult
# 26572             0.0               Too long  Neither easy nor difficult
# 27902            60.0  Appropriate in length                        Easy
# 28213             0.0                    NaN                        Easy
# 28236             NaN  Appropriate in length                        Easy
# 28379           100.0  Appropriate in length  Neither easy nor difficult
# 28381             9.0               Too long                        Easy
# 30449             NaN               Too long  Neither easy nor difficult
# 31166             0.0  Appropriate in length                        Easy
# 32293             NaN  Appropriate in length                        Easy
# 32837            10.0  Appropriate in length  Neither easy nor difficult
# 33000             NaN  Appropriate in length                        Easy
# 33112            50.0  Appropriate in length  Neither easy nor difficult
# 33645             NaN  Appropriate in length                        Easy
# 33720             NaN  Appropriate in length                        Easy
# 33936             0.0  Appropriate in length                        Easy
# 34317             0.0  Appropriate in length  Neither easy nor difficult
# 34523           100.0               Too long                   Difficult
# 34842             NaN  Appropriate in length                        Easy
# 36299             0.0  Appropriate in length  Neither easy nor difficult
# 36329             0.0  Appropriate in length                        Easy
# 37382             NaN  Appropriate in length  Neither easy nor difficult
# 37518             0.0  Appropriate in length  Neither easy nor difficult
# 37930            50.0               Too long  Neither easy nor difficult
# 38219             0.0               Too long                         NaN
# 39643             NaN               Too long                        Easy
# 40066            10.0  Appropriate in length                        Easy
# 40952             NaN  Appropriate in length                        Easy
# 41027             0.0  Appropriate in length  Neither easy nor difficult
#
#       ConvertedCompYearly JobSat
# 529              650000.0    6.0
# 828             1000000.0    8.0
# 1932             945000.0    2.0
# 2171             750000.0    8.0
# 2187            2000000.0    NaN
# 2316            1000000.0   10.0
# 2592             800000.0    8.0
# 3024            1302817.0    NaN
# 5934            1031099.0    NaN
# 6735             650000.0    8.0
# 6802             750000.0    3.0
# 6897            1052581.0    6.0
# 7979            1728025.0    7.0
# 8818            1074062.0    8.0
# 8898            1500000.0    3.0
# 8919             950000.0    NaN
# 9026            1184707.0    NaN
# 9608             798000.0    NaN
# 9732            1188001.0    NaN
# 10624           1000000.0    8.0
# 11607           1273879.0   10.0
# 12143           1332930.0    5.0
# 12723          13818022.0   10.0
# 12814            700000.0    9.0
# 13336            660660.0    7.0
# 13342           1000000.0    3.0
# 13644            803285.0    NaN
# 13755           1500000.0   10.0
# 13763           2048046.0   10.0
# 13790            670000.0    9.0
# 13952            859250.0    6.0
# 14145           1750749.0    9.0
# 14507            750000.0   10.0
# 14674            740517.0    NaN
# 14708            750000.0    1.0
# 15837          16256603.0    NaN
# 16350           1550391.0    NaN
# 16448            800000.0    NaN
# 16560            700000.0    7.0
# 17593           6340564.0    6.0
# 17672           4936778.0    7.0
# 17688           1000000.0    NaN
# 18038           1200000.0   10.0
# 18046            875000.0    9.0
# 19190            750000.0   10.0
# 19244           1200000.0    9.0
# 19267           3367716.0    7.0
# 20728            750000.0    9.0
# 21367           1562898.0    9.0
# 22714            750000.0    6.0
# 22842           2014062.0    8.0
# 22898            750000.0    NaN
# 23288            713372.0    NaN
# 23694           2584118.0    NaN
# 24179            750000.0    9.0
# 24736            700000.0    NaN
# 24754            764327.0    5.0
# 25084           1250348.0    NaN
# 25238            912953.0    NaN
# 25936            810000.0    NaN
# 26080            750000.0   10.0
# 26572           1295242.0    7.0
# 27902           2000000.0    7.0
# 28213            650000.0    5.0
# 28236           1200000.0    NaN
# 28379           9000000.0   10.0
# 28381            650000.0    7.0
# 30449            980887.0    NaN
# 31166            850000.0    8.0
# 32293            720000.0    NaN
# 32837            675000.0    9.0
# 33000           1750000.0    NaN
# 33112            712801.0    7.0
# 33645           1074062.0    NaN
# 33720           2237846.0    NaN
# 33936           1200000.0   10.0
# 34317           1500000.0    3.0
# 34523           2153432.0   10.0
# 34842           1188001.0    NaN
# 36299           1140481.0   10.0
# 36329           1900000.0   10.0
# 37382           1288874.0    NaN
# 37518            900000.0    8.0
# 37930            859250.0    5.0
# 38219           1000000.0   10.0
# 39643           1300000.0    NaN
# 40066            800000.0   10.0
# 40952            750000.0    NaN
# 41027            700000.0   10.0
#
# [89 rows x 114 columns]

# %%
len(outliers)
# Out:
# 89

# %% [markdown]
# <h3>Step 4: Detect Outliers in Compensation</h3>

# %% [markdown]
# Identify outliers in the `ConvertedCompYearly` column using the IQR method.
#
# - Calculate the Interquartile Range (IQR).
#
# - Determine the upper and lower bounds for outliers.
#
# - Count and visualize outliers using a box plot.

# %%
##Write your code here
Q1 = df['ConvertedCompYearly'].quantile(0.25)
Q3 = df['ConvertedCompYearly'].quantile(0.75)

IQR = Q3-Q1
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR

outliers = df[(df['ConvertedCompYearly'] < lower_bound) | (df['ConvertedCompYearly'] > upper_bound)]

print("Outliers:", len(outliers))
# Out:
# Outliers: 978

# %%
plt.figure(figsize=(8,6))
plt.boxplot(df['ConvertedCompYearly'].dropna(), vert=False)
plt.title('ConvertedCompYearly Outliers')
plt.xlabel('Yearly Compensation')
plt.show()

# %% [markdown]
# <h3>Step 5: Remove Outliers and Create a New DataFrame</h3>

# %% [markdown]
# Remove outliers from the dataset.
#
# - Create a new DataFrame excluding rows with outliers in `ConvertedCompYearly`.
# - Validate the size of the new DataFrame.

# %%
##Write your code here
df_no_outliers = df[(df['ConvertedCompYearly']>=lower_bound) & (df['ConvertedCompYearly']<=upper_bound)]

df_no_outliers.shape
# Out:
# (22457, 114)

# %% [markdown]
# <h3>Step 6: Correlation Analysis</h3>

# %% [markdown]
# Analyze the correlation between `Age` (transformed) and other numerical columns.
#
# - Map the `Age` column to approximate numeric values.
#
# - Compute correlations between `Age` and other numeric variables.
#
# - Visualize the correlation matrix.

# %%
##Write your code here
df['Age'].value_counts()
# Out:
# Age
# 25-34 years old       23911
# 35-44 years old       14942
# 18-24 years old       14098
# 45-54 years old        6249
# 55-64 years old        2575
# Under 18 years old     2568
# 65 years or older       772
# Prefer not to say       322
# Name: count, dtype: int64

# %%
# Age Mapping
age_mapping = {
'Under 18 years old': 15,
'18-24 years old': 21,
'25-34 years old': 30,
'35-44 years old': 40,
'45-54 years old': 50,
'55-64 years old': 60,
'65 years or older': 70
}

df_no_outliers['AgeNumeric'] = df_no_outliers['Age'].map(age_mapping)

# %%
# correlation with convertedcompyearly

corr = df_no_outliers[['AgeNumeric', 'ConvertedCompYearly']].corr()
corr
# Out:
#                      AgeNumeric  ConvertedCompYearly
# AgeNumeric             1.000000             0.371753
# ConvertedCompYearly    0.371753             1.000000

# %%
import seaborn as sns

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# <h3> Summary </h3>

# %% [markdown]
# In this lab, you developed essential skills in **Exploratory Data Analysis (EDA)** with a focus on outlier detection and removal. Specifically, you:

# %% [markdown]
# - Loaded and explored the dataset to understand its structure.
#
# - Analyzed the distribution of respondents across industries.
#
# - Identified and removed high compensation outliers using statistical thresholds and the Interquartile Range (IQR) method.
#
# - Performed correlation analysis, including transforming the `Age` column into numeric values for better analysis.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-1|1.1|Madhusudan Moole|Reviewed and updated lab|
# |2024-09-29|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
